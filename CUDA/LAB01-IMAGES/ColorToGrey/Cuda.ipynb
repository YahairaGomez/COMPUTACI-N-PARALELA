# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# **COLOR TO GREY-SCALE**

# %%
# !cd drive/MyDrive/CUDA/LAB01-IMAGES/olorToGrey && nvcc colorToGrey.cu main_parallel.cpp -o RGB_grey_parallel `pkg-config opencv --cflags --libs` && ./RGB_grey_parallel sample.jpg
# Out:
# /bin/bash: line 0: cd: drive/MyDrive/CUDA/LAB01-IMAGES/colorToGrey: No such file or directory

# %% [markdown]
# **COLOR TO BLUR**
