# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !cd drive/MyDrive/CUDA && nvcc sumMatrix.cu && ./a.out

# %%
# !cd drive/MyDrive/CUDA && nvcc mulMatrix.cu && ./a.out
# Out:
# VALORES DE MATRIZ A
#     3   17   13    6    9
#     2   10    3    0   12
#    11    7    2    2    7
#     9    2    9   13   11
#     9    1    4   18   15
#
#
#  VALORES DE MATRIZ A
#     6   15   15   12    1
#
#     7   19    6    6   16
#
#     8    9   10    3   15
#
#     2   18    7   16    2
#
#    13   19   17    4   10
#
# RESULTADO DE MULTIPLICACION
#        370       764       472       309       572
#        262       475       324       141       327
#        226       485       360       240       227
#        309       697       515       399       312
#        324       799       562       474       271
